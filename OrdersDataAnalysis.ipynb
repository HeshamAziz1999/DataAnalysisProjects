# %%
import pandas as pd

# %%
df = pd.read_csv("Orders.csv",skiprows=4)
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 3           NaN        NaN                   NaN         NaN    NaN      NaN
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df.dropna(how = 'all', inplace= True)
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# 5           5.0   1/1/2023                   USA  washington   wh01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df["City"]= df["City"].str.title()
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   rd03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   ad01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   wh01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las Vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   wh01  38.9072
#
# ...

# %%
df['Branch']= df['Branch'].str.upper()
df['Email']= df['Email'].str.lower()
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   WH01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   WH01  38.9072
#
# ...

# %%
df['Phone Number']= df['Phone Number'].str.replace('Tel: ', '')
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   WH01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   WH01  38.9072
#
# ...

# %%
df['Discount'] = df['Discount'].round(0)
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   WH01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   WH01  38.9072
#
# ...

# %%
df['Total_Price'] = df['Quantity'] * df['Unit Price']
df['Cost'] = df['Total_Price'] - df['Discount'].fillna(0)    
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...

# %%
df.insert(9, 'Customer Full Name',df['Customer First Name'].str.title() + " "+ df['Customer Last Name'].str.title())

# %%
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   WH01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   WH01  38.9072
#
# ...

# %%
newCoulms = df['Branch'].str[:2]
df.insert(5 ,'BrCode', newCoulms)

# %%
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...

# %%
df.loc[df['Status']==True, 'Order Status'] = 'Done'
df.loc[df['Status']==False, 'Order Status'] = 'Pending'
df.loc[(df['Status']==False) & (df['Order Date']<='2023-01-01'), 'Order Status'] = 'Canceled'
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...

# %%
def level(row):
    if row > 1000:
        return 'High'
    else:
        return 'Low'
df['Cost Level'] = df['Cost'].apply(level)
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...

# %%
import numpy as np

# %%
df['Discount Description'] = np.where(df['Discount'].isnull(), 'No Discount', (df['Discount']/df['Cost']*100).round(2))
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...

# %%
df.to_excel(r'C:\Users\hesham\Desktop\excel data analysis\MyNewOrders.xlsx',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 0 to 20003
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              20000 non-null  float64
#  1   Order Date            20000 non-null  object
#  2   Country               20000 non-null  object
#  3   City                  20000 non-null  object
#  4   Branch                20000 non-null  object
#  5   BrCode                20000 non-null  object
#  6   Lat                   20000 non-null  float64
#  7   Lng                   20000 non-null  float64
#  8   Customer First Name   20000 non-null  object
#  9   Customer Last Name    20000 non-null  object
#  10  Customer Full Name    20000 non-null  object
#  11  Email                 20000 non-null  object
#  12  Phone Number          20000 non-null  object
#  13  Category              20000 non-null  object
#  14  Sub Category          20000 non-null  object
# ...

# %%
df.describe()
# Out:
#            Order ID           Lat           Lng      Quantity    Unit Price  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean   10000.500000     30.461665     11.339318      1.936750    609.292000
# std     5773.647028      8.126746     53.194139      2.288736    617.976051
# min        1.000000     18.231100   -115.149200      1.000000     29.000000
# 25%     5000.750000     24.453900      2.352200      1.000000    179.000000
# 50%    10000.500000     27.180900     37.134300      1.000000    399.000000
# 75%    15000.250000     36.202100     42.500400      2.000000    899.000000
# max    20000.000000     48.856600     56.324200     13.000000   3999.000000
#
#            Discount   Total_Price          Cost
# count  18889.000000  20000.000000  20000.000000
# mean      65.062841   1181.035250   1119.586650
# std      145.497575   2272.317786   2155.054747
# min        0.000000     29.000000     26.000000
# ...

# %%
df['Quantity'].sum()
# Out:
# 38735.0

# %%
df[['Quantity', 'City']].value_counts()
# Out:
# Quantity  City
# 1.0       Jeddah       2266
#           Abu Dhabi    1598
#           New York     1439
#           Riyadh       1093
#           Cairo        1000
#                        ...
# 7.0       Dubai           2
# 11.0      Homs            2
# 9.0       Fujairah        2
#           Dammam          1
# 5.0       Fujairah        1
# Name: count, Length: 215, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# Laptop             2173
# Tablet             2161
# Smartphone         2091
# VR Headset         2022
# Gaming Console     1957
# Smart Speaker      1939
# Headphones         1936
# Digital Camera     1933
# Fitness Tracker    1895
# Smartwatch         1893
# Name: count, dtype: int64

# %%
df.groupby(['Category', 'Sub Category'])['Cost'].sum()
# Out:
# Category        Sub Category
# Digital Camera  Canon EOS             524891.0
#                 Canon EOS R Series    994785.0
#                 Fujifilm X Series     618661.0
#                 Nikon Coolpix         248769.0
#                 Nikon Z Series        530944.0
#                                         ...
# VR Headset      Oculus Rift S          77157.0
#                 Pimax Vision          574739.0
#                 Samsung Odyssey       324328.0
#                 Sony PlayStation       50591.0
#                 Valve Index           418026.0
# Name: Cost, Length: 81, dtype: float64

# %%
df.groupby(['Category', 'Sub Category'])['Cost'].agg(['sum','mean'])
# Out:
#                                         sum         mean
# Category       Sub Category
# Digital Camera Canon EOS           524891.0  2302.153509
#                Canon EOS R Series  994785.0  4648.528037
#                Fujifilm X Series   618661.0  2588.539749
#                Nikon Coolpix       248769.0  1196.004808
#                Nikon Z Series      530944.0  2516.322275
# ...                                     ...          ...
# VR Headset     Oculus Rift S        77157.0   741.894231
#                Pimax Vision        574739.0  1836.226837
#                Samsung Odyssey     324328.0  2636.813008
#                Sony PlayStation     50591.0   532.536842
#                Valve Index         418026.0  2019.449275
#
# [81 rows x 2 columns]

# %%
df.groupby(['Category', 'Sub Category']).agg({'Quantity':'sum', 'Unit Price':'mean', 'Cost':'sum'})
# Out:
#                                    Quantity   Unit Price      Cost
# Category       Sub Category
# Digital Camera Canon EOS              431.0  1411.719298  524891.0
#                Canon EOS R Series     432.0  2611.149533  994785.0
#                Fujifilm X Series      424.0  1543.351464  618661.0
#                Nikon Coolpix          396.0   627.605769  248769.0
#                Nikon Z Series         380.0  1588.099526  530944.0
# ...                                     ...          ...       ...
# VR Headset     Oculus Rift S          163.0   499.000000   77157.0
#                Pimax Vision           628.0   968.648562  574739.0
#                Samsung Odyssey        229.0  1499.000000  324328.0
#                Sony PlayStation       177.0   299.000000   50591.0
#                Valve Index            401.0  1094.652174  418026.0
#
# [81 rows x 3 columns]

# %%
df.pivot_table(index= 'Country', columns= 'Category', values= 'Quantity', aggfunc= 'sum')
# Out:
# Category              Digital Camera  Fitness Tracker  Gaming Console  \
# Country
# Egypt                          421.0            409.0           526.0
# France                         208.0            194.0           258.0
# Morocco                        112.0            130.0            76.0
# Saudi Arabia                  1210.0           1151.0          1193.0
# Syria                          462.0            512.0           434.0
# USA                            730.0            825.0           791.0
# United Arab Emirates           486.0            510.0           537.0
#
# Category              Headphones  Laptop  Smart Speaker  Smartphone  \
# Country
# Egypt                      514.0   590.0          408.0       474.0
# France                     190.0   267.0          193.0       236.0
# Morocco                     95.0   147.0          133.0       138.0
# Saudi Arabia              1164.0  1332.0         1152.0      1203.0
# ...

# %%
df
# Out:
#        Order ID Order Date               Country        City Branch BrCode  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01     HS
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01     RD
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03     RD
# 4           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01     AD
# 5           5.0   1/1/2023                   USA  Washington   WH01     WH
# ...         ...        ...                   ...         ...    ...    ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01     CS
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01     HS
# 20001   19998.0   1/9/2023                   USA   Las Vegas   LV01     LV
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03     JD
# 20003   20000.0   1/9/2023                   USA  Washington   WH01     WH
#
# ...
