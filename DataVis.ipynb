# %% [markdown]
# ## Welcome to my Data Vis.
# #### now we will Import lib & Data

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('OrdersCleaned.csv')
df
# Out:
#        Order ID  Order Date  Day               Country        City      Lat  \
# 0             1  01/01/2023  Mon                 Syria        homs  34.7326
# 1             2  01/01/2023  Tue          Saudi Arabia      riyadh  24.7136
# 2             3  01/01/2023  Tue          Saudi Arabia      riyadh  24.7743
# 3             4  01/01/2023  Mon  United Arab Emirates   abu dhabi  24.4539
# 4             5  01/01/2023  Wed                   USA  washington  38.9072
# ...         ...         ...  ...                   ...         ...      ...
# 19995     19996  01/09/2023  Tue               Morocco  casablanca  33.5731
# 19996     19997  01/09/2023  Tue                 Syria        homs  34.7326
# 19997     19998  01/09/2023  Wed                   USA   las vegas  36.1699
# 19998     19999  01/09/2023  Mon          Saudi Arabia      jeddah  21.4858
# 19999     20000  01/09/2023  Tue                   USA  washington  38.9072
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## I have already cleaned this data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        20000 non-null  int64
#  1   Order Date      20000 non-null  object
#  2   Day             20000 non-null  object
#  3   Country         20000 non-null  object
#  4   City            20000 non-null  object
#  5   Lat             20000 non-null  float64
#  6   Lng             20000 non-null  float64
#  7   Full Name       20000 non-null  object
#  8   Category        20000 non-null  object
#  9   Sub Category    20000 non-null  object
#  10  Item            20000 non-null  object
#  11  SalesPerson ID  20000 non-null  object
#  12  Quantity        20000 non-null  int64
#  13  Unit Price      20000 non-null  int64
#  14  Discount        20000 non-null  float64
#  15  Total Cost      20000 non-null  float64
#  16  Status          20000 non-null  bool
# ...

# %% [markdown]
# ## This is PLot to show Which country Have Most Orders

# %%
OrdersByCountry= df['Country'].value_counts()

# %%
OrdersByCountry.plot(kind='bar', title = 'OrdersByCountry')
# Out:
# <Axes: title={'center': 'OrdersByCountry'}, xlabel='Country'>

# %% [markdown]
# ## Saudi Arabia Have most Orders
# ### Through this chart, the company can determine which countries it wants to increase sales in.

# %%
Cat_Cost_Total = df.groupby('Category')['Total Cost'].sum()
Cat_Cost_Total
# Out:
# Category
# Digital Camera     2.527700e+06
# Fitness Tracker    2.371728e+05
# Gaming Console     4.944128e+05
# Headphones         4.630230e+05
# Laptop             2.899961e+06
# Smart Speaker      3.213365e+05
# Smartphone         1.364633e+06
# Smartwatch         5.676672e+05
# Tablet             9.346889e+05
# VR Headset         1.495567e+06
# Name: Total Cost, dtype: float64

# %% [markdown]
# ### this Chart show which Categroy Have Biggest Cost

# %%
Cat_Cost_Total.plot(kind='barh', color='green', xlabel='Total Cost(Millions)', title= 'Categroy By Total Cost')
# Out:
# <Axes: title={'center': 'Categroy By Total Cost'}, xlabel='Total Cost(Miluons)', ylabel='Category'>

# %% [markdown]
# ## Laptop & Digital Camera Have biggest Total Cost
# #### We need more Insight to take decision

# %%
Cat_Quan_TotalCost = df.groupby('Category')[['Quantity', 'Total Cost']].sum()

Cat_Quan_TotalCost
# Out:
#                  Quantity    Total Cost
# Category
# Digital Camera       8232  2.527700e+06
# Fitness Tracker      7987  2.371728e+05
# Gaming Console       8276  4.944128e+05
# Headphones           8282  4.630230e+05
# Laptop               9285  2.899961e+06
# Smart Speaker        8294  3.213365e+05
# Smartphone           8899  1.364633e+06
# Smartwatch           8137  5.676672e+05
# Tablet               9272  9.346889e+05
# VR Headset           8557  1.495567e+06

# %% [markdown]
# # This Chart Show Total Cost & Quantity By Categroy
# ##### Through this statement we can make decisions such as: The categories that are more expensive for the company and their quantity is small, the company can reconsider the pricing role

# %%
Sub_x=Cat_Quan_TotalCost.plot(kind='bar',y='Total Cost',ylabel= 'Total Cost (Millions)', color= 'g')
Cat_Quan_TotalCost.plot(kind='line',y='Quantity',ylabel= 'Quantity', color= 'r',secondary_y=True, ax=Sub_x , rot=45)
# Out:
# <Axes: ylabel='Quantity'>

# %%
myData = df.groupby(['Category','Sub Category','Item'], as_index=False)[['Quantity','Unit Price','Discount']].sum()
myData
# Out:
#            Category        Sub Category                   Item  Quantity  \
# 0    Digital Camera           Canon EOS  Canon EOS M50 Mark II       552
# 1    Digital Camera           Canon EOS           Canon EOS R6       409
# 2    Digital Camera  Canon EOS R Series            Canon EOS R       484
# 3    Digital Camera  Canon EOS R Series           Canon EOS R5       422
# 4    Digital Camera   Fujifilm X Series          Fujifilm X-T4       494
# ..              ...                 ...                    ...       ...
# 182      VR Headset        Pimax Vision       Pimax Vision 8KX       443
# 183      VR Headset     Samsung Odyssey     Samsung Odyssey G9       510
# 184      VR Headset    Sony PlayStation         PlayStation VR       418
# 185      VR Headset         Valve Index     Valve Index VR Kit       437
# 186      VR Headset         Valve Index   Valve Index VR Kit 2       420
#
#      Unit Price     Discount
# 0         86966   87578.2017
# 1        234906  188507.5668
# ...

# %%
sns.pairplot(myData)
